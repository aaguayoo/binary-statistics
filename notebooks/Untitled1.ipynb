# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt

from binaryStatistics.velocity_reconstruction import HernandezVTilde
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_file = "../data/667Bp_0.8.csv"
fit_data
data = HernandezVTilde(csv_file)

# %%
data.compute_v_tilde()

# %%
with open("../data/VTil.dat","r") as file:
    lines = file.readlines()
    
    v = []
    v_dist = []
    for line in lines:
        vel, dist = line.strip().split(" ")
        v.append(float(vel))
        v_dist.append(float(dist))

# %%
plt.hist(data.dataframe["v_tilde"], bins=180, density=True)
plt.plot(v,v_dist)
