# %% [markdown]
# # Velocity

# %%
# %load_ext autoreload
# %autoreload 2
import json

import matplotlib.pyplot as plt
import numpy as np
from pydantic import Field
from pydantic.dataclasses import dataclass
from sympy import pi, cos, sin, maximum, lambdify, Interval, minimum, diff, solve
from sympy.core.symbol import Symbol

from binaryStatistics.base_distribution import BaseDistribution
from binaryStatistics.distributions import Uniform, Thermal, PowerLaw
from binaryStatistics.plot_utils import plot_histogram

data_length = 100_000
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# $$
# \tilde{v}\left( \phi, \phi_0, i, e \right) = \sqrt[4]{1 - \sin^2 i \cos^2 \left( \phi - \phi_0 \right)} \sqrt{\frac{1 + e^2 + 2e\cos\phi - \sin^2 i \left( e\sin\phi_0 - \sin \left( \phi - \phi_0 \right) \right)}{1 - e\cos\phi}}
# $$

# %% [markdown]
# ## Eccentricity $e$
#
# Thermal distribution
#
# $$
# p(e) = 2e
# $$

# %%
rand = np.random.uniform(0,1,size=data_length)
thermal = Thermal()
e = thermal.random_sample(0,1,size=data_length)
e = np.sqrt(rand)

# %%
_ = plot_histogram(
    e,
    bins=50,
    density=True,
    color="#ffa500",
    x_params={
        "label": "Eccentricity ($e$)",
        "limits": (0,1),
    },
    file="distributions_files/eccentricity.png"
)

# %%
_ = plot_histogram(
    e**2,
    bins=50,
    density=True,
    color="#ffa500",
    x_params={
        "label": "Eccentricity squared ($e^2$)",
        "limits": (0,1),
    },
    file="distributions_files/eccentricity_squared.png"
)

# %% [markdown]
# ## Orbit angle $i$
#
# $$
# p(i) = \sin(i)
# $$

# %%
@dataclass
class Sine(BaseDistribution):
    
    dist_parameters: dict = Field(default={})
    
    def __post_init_post_parse__(self):
        super().__init__(self.dist_parameters)
        
    def distribution(self, i):
        return np.sin(i)

# %%
sine = Sine()
i = sine.random_sample(0,np.pi/2,size=data_length)
i = np.arccos(rand)

# %%
_ = plot_histogram(
    i,
    bins=50,
    density=True,
    color="gray",
    x_params={
        "label": "$i$ ($rad$)",
        "limits": (0, np.pi/2)
    },
    pi_factor=8,
    file="distributions_files/orbit_angle.png"
)

# %% [markdown]
# ## Phase angle $\phi$
#
# $$
# p\left( \phi | e \right) = \frac{\left( 1 - e^2\right)^{3/2}}{2\pi \left( 1 + e \cos\phi \right)^2},
# $$

# %%
@dataclass
class PhiAngle(BaseDistribution):
    
    dist_parameters: dict = Field(default={})
    
    def __post_init_post_parse__(self):
        super().__init__(self.dist_parameters)
        self.phi = Symbol("phi")
        self.e = Symbol("e")
        
        
    def distribution(self, phi, e):
        
        if isinstance(phi, Symbol):
            return ((1.0 - e**2.0)**(3.0/2.0))/(2*pi*(1 + e*cos(phi))**2)
        return ((1.0 - e**2.0)**(3.0/2.0))/(2*np.pi*(1 + e*np.cos(phi))**2)
    
    def get_pdf_derivative_phi(self):
        pdf = phi_angle.distribution(x,e=e)
        return diff(pdf, phi)

    def get_pdf_maximum(self):
        dpdf = self.get_pdf_derivative_phi()
        roots = solve(dpdf, phi)

# %%
phi_4 = []
for index in range(data_length):
    LI = 0
    while LI < 1:
        E = e[index]
        c = (1 - E**2)/(2*np.pi*(1 - E)**2)
        base = 2*np.pi
        Phi = np.random.uniform()*base
        pPhi = np.random.uniform()*c 
        if pPhi <= phi_angle.distribution(Phi,E):
            LI = 2
            phi_4.append(Phi)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 8
#       6 _phi = Symbol("phi")
#       7 pdf = phi_angle.distribution(_phi, e=E)
# ----> 8 c = maximum(pdf,_phi,Interval(0,2*pi))
#       9 base = 2*np.pi
#      10 Phi = np.random.uniform()*base
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/calculus/util.py:792, in maximum(f, symbol, domain)
#     789     if domain is S.EmptySet:
#     790         raise ValueError("Maximum value not defined for empty domain.")
# --> 792     return function_range(f, symbol, domain).sup
#     793 else:
#     794     raise ValueError("%s is not a valid symbol." % symbol)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/calculus/util.py:146, in function_range(f, symbol, domain)
#     143 if domain is S.EmptySet:
#     144     return S.EmptySet
# --> 146 period = periodicity(f, symbol)
#     147 if period == S.Zero:
#     148     # the expression is constant wrt symbol
#     149     return FiniteSet(f.expand())
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/calculus/util.py:485, in periodicity(f, symbol, check)
#     483 coeff, g = f.as_independent(symbol, as_Add=False)
#     484 if isinstance(g, TrigonometricFunction) or not equal_valued(coeff, 1):
# --> 485     period = periodicity(g, symbol)
#     486 else:
#     487     period = _periodicity(g.args, symbol)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/calculus/util.py:427, in periodicity(f, symbol, check)
#     424 if isinstance(f, Relational):
#     425     f = f.lhs - f.rhs
# --> 427 f = f.simplify()
#     429 if symbol not in f.free_symbols:
#     430     return S.Zero
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/basic.py:1853, in Basic.simplify(self, **kwargs)
#    1851 """See the simplify function in sympy.simplify"""
#    1852 from sympy.simplify.simplify import simplify
# -> 1853 return simplify(self, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/simplify.py:725, in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     722     from sympy.physics.units.util import quantity_simplify
#     723     expr = quantity_simplify(expr)
# --> 725 short = shorter(powsimp(expr, combine='exp', deep=True), powsimp(expr), expr)
#     726 short = shorter(short, cancel(short))
#     727 short = shorter(short, factor_terms(short), expand_power_exp(expand_mul(short)))
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/powsimp.py:117, in powsimp(expr, deep, combine, force, measure)
#     114     return expr
#     116 if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 117     expr = expr.func(*[recurse(w) for w in expr.args])
#     119 if expr.is_Pow:
#     120     return recurse(expr*_y, deep=False)/_y
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/powsimp.py:117, in <listcomp>(.0)
#     114     return expr
#     116 if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 117     expr = expr.func(*[recurse(w) for w in expr.args])
#     119 if expr.is_Pow:
#     120     return recurse(expr*_y, deep=False)/_y
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/powsimp.py:108, in powsimp.<locals>.recurse(arg, **kwargs)
#     106 _force = kwargs.get('force', force)
#     107 _measure = kwargs.get('measure', measure)
# --> 108 return powsimp(arg, _deep, _combine, _force, _measure)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/powsimp.py:117, in powsimp(expr, deep, combine, force, measure)
#     114     return expr
#     116 if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 117     expr = expr.func(*[recurse(w) for w in expr.args])
#     119 if expr.is_Pow:
#     120     return recurse(expr*_y, deep=False)/_y
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/powsimp.py:117, in <listcomp>(.0)
#     114     return expr
#     116 if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 117     expr = expr.func(*[recurse(w) for w in expr.args])
#     119 if expr.is_Pow:
#     120     return recurse(expr*_y, deep=False)/_y
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/powsimp.py:108, in powsimp.<locals>.recurse(arg, **kwargs)
#     106 _force = kwargs.get('force', force)
#     107 _measure = kwargs.get('measure', measure)
# --> 108 return powsimp(arg, _deep, _combine, _force, _measure)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/simplify/powsimp.py:191, in powsimp(expr, deep, combine, force, measure)
#     189 if bpos:
#     190     binv = 1/b
# --> 191     if b != binv and binv in c_powers:
#     192         if b.as_numer_denom()[0] is S.One:
#     193             c_powers.pop(b)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/numbers.py:1467, in Float.__hash__(self)
#    1466 def __hash__(self):
# -> 1467     return super().__hash__()
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/numbers.py:809, in Number.__hash__(self)
#     808 def __hash__(self):
# --> 809     return super().__hash__()
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/basic.py:193, in Basic.__hash__(self)
#     189 def __hash__(self) -> int:
#     190     # hash cannot be cached using cache_it because infinite recurrence
#     191     # occurs as hash is needed for setting cache dictionary keys
#     192     h = self._mhash
# --> 193     if h is None:
#     194         h = hash((type(self).__name__,) + self._hashable_content())
#     195         self._mhash = h
#
# KeyboardInterrupt:

# %%
x = Symbol("x")
e = Symbol("e")

# %%
phi_angle = PhiAngle()

# %%
f = phi_angle.distribution(x,e=e)

# %%
df = diff(f,x)

# %%
df
# Out:
# e*(1.0 - e**2.0)**1.5*sin(x)/(pi*(e*cos(x) + 1)**3)

# %%
lambdify(e, lambdify(x,f)(0))(0.3)
# Out:
# 0.08175145963096095

# %%
lambdify(e, lambdify(x,f)(np.pi))(0.3)
# Out:
# 0.28195911587004907

# %%
pdf = phi_angle.distribution(x, e=e[3])

# %%
pdf
# Out:
# 0.237868405734947/(pi*(0.624970208522509*cos(x) + 1)**2)

# %%
phi_angle = PhiAngle(
    dist_parameters={
        "e": e,
    }
)
phi = phi_angle.random_sample(0.0,2*np.pi,size=data_length)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 6
#       1 phi_angle = PhiAngle(
#       2     dist_parameters={
#       3         "e": e,
#       4     }
#       5 )
# ----> 6 phi = phi_angle.random_sample(0.0,2*np.pi,size=data_length)
#
# File ~/DriveCiencias/AyudantiaSNI/binary-statistics/binary-statistics/python/binaryStatistics/base_distribution.py:72, in BaseDistribution.random_sample(self, x_min, x_max, size)
#      70 """Random sample distribution."""
#      71 x = np.linspace(x_min, x_max, size)
# ---> 72 cdf = self.cdf(x)
#      74 cdf_inv = interpolate.interp1d(cdf, x, fill_value="extrapolate")
#      76 try:
#
# File ~/DriveCiencias/AyudantiaSNI/binary-statistics/binary-statistics/python/binaryStatistics/base_distribution.py:32, in BaseDistribution.cdf(self, x)
#      30 def cdf(self, x: np.array):
#      31     """Cumulative Distribution Function."""
# ---> 32     self.__compute_pdf_norm(x)
#      33     pdf_values = self._pdf(x)
#      34     cumulative_sum = np.cumsum(pdf_values * self.norm_factor)
#
# File ~/DriveCiencias/AyudantiaSNI/binary-statistics/binary-statistics/python/binaryStatistics/base_distribution.py:28, in BaseDistribution.__compute_pdf_norm(self, x)
#      26 self.norm_factor = (x.max() - x.min()) / len(x)
#      27 if not hasattr(self, "norm"):
# ---> 28     self.norm = 1.0 / np.sum(self._pdf(x) * self.norm_factor)
#
# Cell In[11], line 13, in PhiAngle.distribution(self, phi, e)
#      11 if isinstance(phi, Symbol):
#      12     return ((1.0 - e**2.0)**(3.0/2.0))/(2*pi*(1 + e*cos(phi))**2)
# ---> 13 return ((1.0 - e**2.0)**(3.0/2.0))/(2*np.pi*(1 + e*np.cos(phi))**2)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/decorators.py:106, in call_highest_priority.<locals>.priority_decorator.<locals>.binary_op_wrapper(self, other)
#     104         if f is not None:
#     105             return f(self)
# --> 106 return func(self, other)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/expr.py:218, in Expr.__mul__(self, other)
#     215 @sympify_return([('other', 'Expr')], NotImplemented)
#     216 @call_highest_priority('__rmul__')
#     217 def __mul__(self, other):
# --> 218     return Mul(self, other)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/mul.py:365, in Mul.flatten(cls, seq)
#     363     return [S.NaN], [], None
#     364 elif coeff.is_Number or isinstance(coeff, AccumBounds):  # it could be zoo
# --> 365     coeff *= o
#     366     if coeff is S.NaN:
#     367         # we know for sure the result will be nan
#     368         return [S.NaN], [], None
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/numbers.py:2213, in Integer.__mul__(self, other)
#    2211     elif isinstance(other, Rational):
#    2212         return Rational(self.p*other.p, other.q, igcd(self.p, other.q))
# -> 2213     return Rational.__mul__(self, other)
#    2214 return Rational.__mul__(self, other)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/decorators.py:65, in __sympifyit.<locals>.__sympifyit_wrapper(a, b)
#      63     if not hasattr(b, '_op_priority'):
#      64         b = sympify(b, strict=True)
# ---> 65     return func(a, b)
#      66 except SympifyError:
#      67     return retval
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/numbers.py:1747, in Rational.__mul__(self, other)
#    1745     return Rational(self.p*other.p, self.q*other.q, igcd(self.p, other.q)*igcd(self.q, other.p))
#    1746 elif isinstance(other, Float):
# -> 1747     return other*self
#    1748 else:
#    1749     return Number.__mul__(self, other)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/decorators.py:65, in __sympifyit.<locals>.__sympifyit_wrapper(a, b)
#      63     if not hasattr(b, '_op_priority'):
#      64         b = sympify(b, strict=True)
# ---> 65     return func(a, b)
#      66 except SympifyError:
#      67     return retval
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/numbers.py:1298, in Float.__mul__(self, other)
#    1296 if isinstance(other, Number) and global_parameters.evaluate:
#    1297     rhs, prec = other._as_mpf_op(self._prec)
# -> 1298     return Float._new(mlib.mpf_mul(self._mpf_, rhs, prec, rnd), prec)
#    1299 return Number.__mul__(self, other)
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/numbers.py:1193, in Float._new(cls, _mpf_, _prec, zero)
#    1190 elif _mpf_ == _mpf_ninf:
#    1191     return S.NegativeInfinity
# -> 1193 obj = Expr.__new__(cls)
#    1194 obj._mpf_ = mpf_norm(_mpf_, _prec)
#    1195 obj._prec = _prec
#
# File ~/.cache/pypoetry/virtualenvs/binaries-statistics-OFq7OFuv-py3.10/lib/python3.10/site-packages/sympy/core/basic.py:163, in Basic.__new__(cls, *args)
#     162 def __new__(cls, *args):
# --> 163     obj = object.__new__(cls)
#     164     obj._assumptions = cls.default_assumptions
#     165     obj._mhash = None  # will be set by __hash__ method.
#
# KeyboardInterrupt:

# %%
phi_2 = []
for i in range(len(phi)):
    LI = 0
    while LI < 1:
        ecc = np.sqrt(np.random.uniform())
        PhiT = np.random.uniform(0,1)*2*np.pi
        RnT = np.random.uniform(0,1)
        PPhi = np.random.uniform(0,1)/(1.0 - e[i])**2
        temp = (1 + e[i]*np.cos(PhiT))**2
        if PPhi < (1.0/temp):
            LI = 2;
            Phi=PhiT
            phi_2.append(Phi)

# %%
_=plt.hist(phi,bins=300, density=True, alpha=0.5)
_=plt.hist(phi_2,bins=300, density=True, alpha=0.5)

# %%
np.median(phi), np.median(phi_2)
# Out:
# (3.1439681931751036, 3.142955550280072)

# %%
_ = plot_histogram(
    phi,
    bins=50,
    density=True,
    color="#6d8000",
    x_params={
        "label": "$\phi$ ($rad$)",
        "limits": (0,2*np.pi)
    },
    pi_factor=2,
    file="distributions_files/phase_angle.png"
)

# %%
_ = plot_histogram(
    phi_2,
    bins=50,
    density=True,
    color="#6d8000",
    x_params={
        "label": "$\phi$ ($rad$)",
        "limits": (0,2*np.pi)
    },
    pi_factor=2,
    file="distributions_files/phase_angle.png"
)

# %% [markdown]
# ## Initial phase angle $\phi_0$
#
# $$
# p \left(\phi_0\right) = \mathcal{U} \left\lbrace 0, 2\pi \right\rbrace
# $$

# %%
uniform = Uniform()
phi_0 = uniform.random_sample(0,2*np.pi,size=data_length)
phi_0 = np.random.uniform(0,2*np.pi, size=data_length)

# %%
_ = plot_histogram(
    phi_0,
    bins=50,
    density=True,
    color="#ccac00",
    x_params={
        "label": "$\\phi_0$ ($rad$)",
        "limits": (0, 2*np.pi)
    },
    pi_factor=2,
    file="distributions_files/initial_phase_angle.png"
)

# %% [markdown]
# ## Velocity $\tilde{v}$

# %%
@dataclass
class VelTilde(BaseDistribution):
    
    dist_parameters: dict = Field(default={})
    
    def __post_init_post_parse__(self):
        super().__init__(self.dist_parameters)
        
    def distribution(self, phi, phi_0, i, e):
        #term_1 = (1.0 + e**2 + 2*e*np.cos(phi))/(1 + e*np.cos(phi))
        #term_3 = 1.0 - (np.sin(i)**2)*(np.cos(alpha + phi - phi_0)**2)
        temp2 = 1.0 - (np.sin(i)**2)*(np.cos(phi - phi_0)**2)
        temp2 = temp2**0.25
        
        temp1 = e*np.sin(phi_0) - np.sin(phi-phi_0)
        temp1 = temp1*temp1
        
        temp3 = (1.0 + e*e + 2*e*np.cos(phi) - np.sin(i)*np.sin(i)*temp1)/(1.0 + e*np.cos(phi))
        temp3 = np.sqrt(temp3)
        
        return temp2*temp3

# %%
e = thermal.random_sample(0,1,size=data_length)
i = sine.random_sample(0,np.pi/2,size=data_length)
phi_0 = uniform.random_sample(0,2*np.pi,size=data_length)
phi_angle = PhiAngle(
    dist_parameters={
        "e":e
    }
)
phi = phi_angle.random_sample(0.0,2*np.pi,size=data_length)

# %%
phi_4 = []
for index in range(data_length):
    LI = 0
    while LI < 1:
        E = e[index]
        c = (1 - E**2)/(2*np.pi*(1 - E)**2)
        base = 2*np.pi
        Phi = np.random.uniform()*base
        pPhi = np.random.uniform()*c 
        if pPhi <= phi_angle.distribution(Phi,E):
            LI = 2
            phi_4.append(Phi)

# %%
_=plt.hist(phi_4, bins=30, density=True)

# %%
# Rejection method
phi_2 = []
for index in range(len(phi)):
    LI = 0
    while LI < 1:
        PhiT = np.random.uniform(0,1)*2*np.pi
        RnT = np.random.uniform(0,1)
        PPhi = np.random.uniform(0,1)/(1.0 - e[index])**2
        temp = (1 + e[index]*np.cos(PhiT))**2
        if PPhi < (1.0/temp):
            LI = 2;
            Phi=PhiT
            phi_2.append(Phi)

# %%
vel = VelTilde()
v_tilde_1 = vel.distribution(
    phi_4, 
    phi_0,
    i,
    e
)
v_tilde_2 = vel.distribution(
    phi_2, 
    phi_0,
    i,
    e
)

# %%
_=plt.hist(v_tilde_1, bins=300, density=True)
_=plt.hist(v_tilde_2, bins=300, density=True)

# %%
fig, ax = plot_histogram(
    v_tilde_1,
    bins=300,
    density=True,
    color="#7c6eae",
    x_params={
        "label":"$\\tilde{v}$",
    },
    file="distributions_files/v2d.png"
)

# %%
with open("../VTil.dat","r") as file:
    lines = file.readlines()
    
    v = []
    v_dist = []
    for line in lines:
        vel, dist = line.strip().split(" ")
        v.append(float(vel))
        v_dist.append(float(dist))

# %%
ax.plot(v, v_dist)
fig
